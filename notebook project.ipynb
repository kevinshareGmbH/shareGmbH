# %% [markdown]
# credits usage with Appinio

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#          Date                           Name  No. of participants  \
# 0  01.07.2019  Redesign_Sonnenstaub_Design A                200.0
# 1  02.07.2019  Redesign_Sonnenstaub_Design B                200.0
# 2  29.08.2019              Redesign_Design A                200.0
# 3  29.08.2019              Redesign_Design B                200.0
# 4  29.08.2019              Redesign_Design C                200.0
#
#    Credits / participant  Total number of credits Price per credit  \
# 0                    2.5                    500.0              1.3
# 1                    2.5                    500.0              1.3
# 2                    2.5                    500.0              1.3
# 3                    2.5                    500.0              1.3
# 4                    2.5                    500.0              1.3
#
#    Total price Note Louise
# 0          650         NaN
# 1          650         NaN
# 2          650         NaN
# 3          650         NaN
# ...
